# %%
import pandas as pd
import numpy as np
import csv
import json
import matplotlib.pyplot as plt
import ast

from sklearn import linear_model

# %% [markdown]
# # Data pre-processing/cleaning

# %%
# !pip3 install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: scikit-learn in /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.20.3)
# Requirement already satisfied: joblib>=0.11 in /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=7c4760df1e5ee3d4aaceae004ec22d85ff9962e8ab5b64e0172887e0e1c2b457
#   Stored in directory: /Users/chaninderrishi/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
df = pd.read_csv('emily_election.csv')
df#contains no null values
# Out:
#        Unnamed: 0                                 ad_creative_bodies  \
# 0               0
# 1               1  !!!The government cannot fight CORRUPTION - th...
# 2               2  !!🚨Endorsement Alert🚨!! \n\nThank you Byron Po...
# 3               3  " An astute CPA told me 45 years ago, Math nev...
# 4               4  "....Framingham should not go back to the ways...
# ...           ...                                                ...
# 11732       11732  🛡Protecting Taxpayers.\n📈Growing Our Economy.\...
# 11733       11733  🟢Today is September 26th. \n🟡On October 23rd t...
# 11734       11734  🤔 We get it—the 2022 midterm elections seem fa...
# 11735       11735  🥳❄️  Join new and old friends for our annual h...
# 11736       11736  🩺 For seniors, open enrollment ends TUESDAY, 1...
#
#                                 demographic_distribution  \
# 0      [[{'percentage': '0.000876', 'age': '45-54', '...
# 1      [[{'percentage': '0.000933', 'age': '18-24', '...
# 2      [[{'percentage': '0.004039', 'age': '65+', 'ge...
# 3      [[{'percentage': '0.00112', 'age': '18-24', 'g...
# 4      [[{'percentage': '0.004255', 'age': '45-54', '...
# ...                                                  ...
# 11732  [[{'percentage': '0.001263', 'age': '45-54', '...
# 11733  [[{'percentage': '0.003527', 'age': '45-54', '...
# 11734  [[{'percentage': '0.029101', 'age': '35-44', '...
# 11735  [[{'percentage': '0.005556', 'age': '45-54', '...
# 11736  [[{'percentage': '0.008522', 'age': '65+', 'ge...
#
#                                       delivery_by_region  \
# 0      [[{'percentage': '1', 'region': 'New York'}], ...
# 1      [[{'percentage': '0.00185', 'region': 'Rhode I...
# 2      [[{'percentage': '0.002281', 'region': 'Unknow...
# 3      [[{'percentage': '1', 'region': 'Ohio'}], [{'p...
# 4      [[{'percentage': '1', 'region': 'Massachusetts...
# ...                                                  ...
# 11732      [[{'percentage': '1', 'region': 'New York'}]]
# 11733  [[{'percentage': '0.012302', 'region': 'Florid...
# 11734  [[{'percentage': '0.005291', 'region': 'Alabam...
# 11735         [[{'percentage': '1', 'region': 'Texas'}]]
# 11736  [[{'percentage': '0.994661', 'region': 'Arizon...
#
#                                  estimated_audience_size  \
# 0      [{'lower_bound': '10001', 'upper_bound': '5000...
# 1                           [{'lower_bound': '1000001'}]
# 2      [{'lower_bound': '100001', 'upper_bound': '500...
# 3      [{'lower_bound': '100001', 'upper_bound': '500...
# 4      [{'lower_bound': '50001', 'upper_bound': '1000...
# ...                                                  ...
# 11732  [{'lower_bound': '5001', 'upper_bound': '10000'}]
# 11733  [{'lower_bound': '100001', 'upper_bound': '500...
# 11734  [{'lower_bound': '1000001'}, {'lower_bound': '...
# 11735   [{'lower_bound': '1001', 'upper_bound': '5000'}]
# 11736  [{'lower_bound': '100001', 'upper_bound': '500...
#
#                                                    spend  \
# 0      [{'lower_bound': '300', 'upper_bound': '399'},...
# 1            [{'lower_bound': '0', 'upper_bound': '99'}]
# 2         [{'lower_bound': '100', 'upper_bound': '199'}]
# 3      [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# 4      [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# ...                                                  ...
# 11732        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11733        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11734  [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# 11735        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11736  [{'lower_bound': '0', 'upper_bound': '99'}, {'...
#
#                                              impressions  \
# 0      [{'lower_bound': '8000', 'upper_bound': '8999'...
# 1       [{'lower_bound': '1000', 'upper_bound': '1999'}]
# 2       [{'lower_bound': '2000', 'upper_bound': '2999'}]
# 3      [{'lower_bound': '2000', 'upper_bound': '2999'...
# 4      [{'lower_bound': '0', 'upper_bound': '999'}, {...
# ...                                                  ...
# 11732   [{'lower_bound': '4000', 'upper_bound': '4999'}]
# 11733   [{'lower_bound': '1000', 'upper_bound': '1999'}]
# 11734  [{'lower_bound': '0', 'upper_bound': '999'}, {...
# 11735   [{'lower_bound': '2000', 'upper_bound': '2999'}]
# 11736  [{'lower_bound': '10000', 'upper_bound': '1499...
#
#                                   ad_delivery_start_time  \
# 0      ['2021-10-30', '2021-10-27', '2021-10-20', '20...
# 1                                         ['2021-12-16']
# 2                                         ['2021-11-16']
# 3                           ['2021-12-22', '2021-11-14']
# 4                           ['2021-11-01', '2021-10-27']
# ...                                                  ...
# 11732                                     ['2021-10-31']
# 11733                                     ['2021-09-26']
# 11734  ['2021-10-15', '2021-10-15', '2021-10-15', '20...
# 11735                                     ['2021-11-18']
# 11736                       ['2021-11-29', '2021-11-29']
#
#                                    ad_delivery_stop_time  \
# 0      ['2021-11-02', '2021-10-31', '2021-10-23', '20...
# 1                                         ['2021-12-23']
# 2                                         ['2021-11-22']
# 3                           ['2022-01-10', '2021-11-17']
# 4                           ['2021-11-02', '2021-11-01']
# ...                                                  ...
# 11732                                     ['2021-11-01']
# 11733                                     ['2021-09-30']
# 11734  ['2021-10-18', '2021-10-19', '2021-10-18', '20...
# 11735                                     ['2021-12-14']
# 11736                       ['2021-12-02', '2021-12-02']
#
#                         cumulative_impressions_by_region  cum_spend  \
# 0      {'New York': 27999.0, 'Georgia': 7000.0, 'Conn...     1347.5
# 1      {'Rhode Island': 1000.0, 'New York': 1000.0, '...       49.5
# 2              {'Unknown': 2499.5, 'New Mexico': 2499.5}      149.5
# 3                                       {'Ohio': 5999.0}       99.0
# 4      {'Massachusetts': 499.5, 'Connecticut': 0.0, '...       99.0
# ...                                                  ...        ...
# 11732                               {'New York': 4499.5}       49.5
# 11733  {'Florida': 1499.5, 'Massachusetts': 1499.5, '...       49.5
# 11734  {'Alabama': 43999.0, 'Ohio': 44998.0, 'Maine':...      992.0
# 11735                                  {'Texas': 2499.5}       49.5
# 11736  {'Arizona': 13999.0, 'California': 13999.0, 'N...       99.0
#
#                                         days_between_ads  \
# 0      TimedeltaIndex(['3 days', '4 days', '3 days', ...
# 1      TimedeltaIndex(['7 days'], dtype='timedelta64[...
# 2      TimedeltaIndex(['6 days'], dtype='timedelta64[...
# 3      TimedeltaIndex(['19 days', '3 days'], dtype='t...
# 4      TimedeltaIndex(['1 days', '5 days'], dtype='ti...
# ...                                                  ...
# 11732  TimedeltaIndex(['1 days'], dtype='timedelta64[...
# 11733  TimedeltaIndex(['4 days'], dtype='timedelta64[...
# 11734  TimedeltaIndex([ '3 days',  '4 days',  '3 days...
# 11735  TimedeltaIndex(['26 days'], dtype='timedelta64...
# 11736  TimedeltaIndex(['3 days', '3 days'], dtype='ti...
#
#       cumulative_ad_runtime                            cumulative_est_audience
# 0                   33 days  {'New York': 1026000.0, 'Georgia': 1005001.0, ...
# 1                    7 days  {'Rhode Island': 1000001.0, 'New York': 100000...
# 2                    6 days      {'Unknown': 300000.5, 'New Mexico': 300000.5}
# 3                   22 days                                 {'Ohio': 600001.0}
# 4                    6 days  {'Massachusetts': 1000500.5, 'Connecticut': 10...
# ...                     ...                                                ...
# 11732                1 days                               {'New York': 7500.5}
# 11733                4 days  {'Florida': 300000.5, 'Massachusetts': 300000....
# 11734              128 days  {'Alabama': 1035000.0, 'Ohio': 1035999.0, 'Mai...
# 11735               26 days                                  {'Texas': 3000.5}
# 11736                6 days  {'Arizona': 600001.0, 'California': 600001.0, ...
#
# [11737 rows x 14 columns]

# %% [markdown]
# # Model 1: 2 features

# %%
"""
GOAL: predict spend for every region
FEATURES:
1. ad runtime
2. cumulative spend
"""
# Out:
# '\nGOAL: predict spend for every region\nFEATURES:\n1. ad runtime\n2. cumulative spend\n'

# %%
df['cum_spend']
# Out:
# 0        1347.5
# 1          49.5
# 2         149.5
# 3          99.0
# 4          99.0
#           ...
# 11732      49.5
# 11733      49.5
# 11734     992.0
# 11735      49.5
# 11736      99.0
# Name: cum_spend, Length: 11737, dtype: float64

# %%
df['spend'] = df['cum_spend']

# %%
df['runtime'] = df['cumulative_ad_runtime'].apply(lambda s: int(s.split('days')[0]))
df['impressions'] = df['cumulative_impressions_by_region'].apply(lambda d: ast.literal_eval(d))
df['impressions'] = df['impressions'].apply(lambda d: np.array(list(d.values())).sum())

#feature 3 (for later)
df['audience_size'] = df['cumulative_est_audience'].apply(lambda d: ast.literal_eval(d))
df['audience_size'] = df['audience_size'].apply(lambda d: np.array(list(d.values())).sum())

#data = df[['runtime', 'spend', 'impressions']]
data = df[['runtime', 'spend', 'audience_size','impressions']]
data
# Out:
#        runtime   spend  audience_size  impressions
# 0           33  1347.5     45631045.0     270998.0
# 1            7    49.5     51000051.0      51000.0
# 2            6   149.5       600001.0       4999.0
# 3           22    99.0       600001.0       5999.0
# 4            6    99.0      3000502.5        499.5
# ...        ...     ...            ...          ...
# 11732        1    49.5         7500.5       4499.5
# 11733        4    49.5      9600016.0      47984.0
# 11734      128   992.0     52812972.0    2271921.0
# 11735       26    49.5         3000.5       2499.5
# 11736        6    99.0      2400004.0      55996.0
#
# [11737 rows x 4 columns]

# %%
msk = np.random.rand(len(data)) < 0.8
train = data[msk]
test = data[~msk]

# %%
train.head(30)
# Out:
#     runtime   spend  audience_size  impressions
# 0        33  1347.5     45631045.0     270998.0
# 1         7    49.5     51000051.0      51000.0
# 2         6   149.5       600001.0       4999.0
# 3        22    99.0       600001.0       5999.0
# 4         6    99.0      3000502.5        499.5
# 5        34   398.0      1005001.0      55000.0
# 6        12   148.5        90001.5       2498.5
# 7         2    49.5        30000.5       1499.5
# 9        14   349.5         3000.5      12499.5
# 10        4    49.5     51000051.0     255000.0
# 11        3    49.5        60001.0       2999.0
# 12       21   448.5       712523.5     446476.5
# 13        9    49.5         7500.5        499.5
# 14      103   445.5       270004.5       7495.5
# 15        7    49.5         7500.5       2499.5
# 16        4   449.5        30000.5       7499.5
# 17        4    49.5        30000.5        499.5
# 20        9  1249.5        30000.5      64999.5
# 21        4    49.5         7500.5        499.5
# 22       10    49.5        30000.5       2499.5
# 24       11  1399.0        60001.0      50999.0
# 25        3    49.5        30000.5       1499.5
# 27        4    49.5        30000.5       5499.5
# 28       29   497.0        51004.0      23996.0
# 29       58  1096.0        33004.0      39996.0
# 32        6    49.5       300000.5       1499.5
# 33        3    49.5         7500.5        499.5
# 34        3    49.5        30000.5        499.5
# 35        9   148.5     50100050.0     200000.0
# 36        6   149.5        75000.5       7499.5

# %% [markdown]
# # Visualizing the Data

# %% [markdown]
# ## Raw visualizations

# %%
plt.scatter(train.runtime, train.impressions,  color='blue')
plt.xlabel("Runtime")
plt.ylabel("Impressions")
plt.show()

# %%
plt.scatter(train.spend, train.impressions,  color='blue')
plt.xlabel("Spend")
plt.ylabel("Impressions")
plt.show()

# %%
plt.scatter(train.runtime, train.impressions,  color='blue')
plt.xlabel("Runtime")
plt.ylabel("Impressions")
plt.show()

# %% [markdown]
# ## After applying log transformation

# %%
plt.scatter(np.log(train.runtime), np.log(train.impressions),  color='blue')
plt.xlabel("Runtime")
plt.ylabel("Impressions")
plt.show()
# Out:
# /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(np.log2(train.spend), np.log10(train.impressions),  color='blue')
plt.xlabel("Spend")
plt.ylabel("Impressions")
plt.show()
# Out:
# /Users/chaninderrishi/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#new_train = train[train['impressions'] < 1000000]
new_train = train[(train['spend'] > 250)]
new_train = new_train[new_train['runtime']>4]
new_train.shape
# Out:
# (2053, 4)

# %%
plt.scatter(np.log(new_train.spend), np.log10(new_train.impressions),  color='blue')
plt.xlabel("Spend")
plt.ylabel("Impressions")
plt.show()

# %%
plt.scatter(np.log(new_train.runtime), np.log10(new_train.impressions),  color='blue')
plt.xlabel("Runtime")
plt.ylabel("Impressions")
plt.show()

# %%
#this model predicts impressions given the runtime and the spend

regr = linear_model.LinearRegression()
new_train['log_runtime'] = np.log(new_train['runtime'])
new_train['log_spend'] = np.log(new_train['spend'])
new_train['log_impressions'] = np.log(new_train['impressions'])
new_train.replace([np.inf, -np.inf], np.nan, inplace=True)
new_train.dropna(inplace=True)
x = np.asanyarray(new_train[['log_runtime', 'log_spend']])
y = np.asanyarray(new_train[['log_impressions']])
regr.fit (x, y)
y_pred= regr.predict(new_train[['log_runtime', 'log_spend']])
# # The coefficients
print(regr.coef_)
print('R-squared score: %.2f' % regr.score(x, y))
print('Standard Deviation: %.2f' % np.sqrt(sum((y - y_pred)**2) / (len(y) - 2)))
# Out:
# [[0.31505594 1.12647059]]
# R-squared score: 0.45
# Standard Deviation: 1.63

# %%
#filtering for ads with a spend of over 250,000 and runtime of over 4 days

test = test[(test['spend'] > 250)]
test = test[test['runtime']> 4]
test['log_runtime'] = np.log(test['runtime'])
test['log_spend'] = np.log(test['spend'])
test['log_impressions'] = np.log(test['impressions'])
test.replace([np.inf, -np.inf], np.nan, inplace=True)
test.dropna(inplace=True)

# %%
#result of passing in the test set into the linear model
y_hat= regr.predict(test[['log_runtime', 'log_spend']])

x = np.asanyarray(test[['log_runtime', 'log_spend']]) #test test
y = np.asanyarray(test[['log_impressions']]) # true outputs

# Explained variance score
print('R-squared score: %.2f' % regr.score(x, y))
print('Root mean squared error: %.2f' % np.sqrt(sum((y - y_hat)**2) / (len(y) - 2)))""
# Out:
# R-squared score: 0.43
# Root mean squared error: 1.67

# %%
#make your prediction

#e.g: regr.predict([[RUNTIME IN DAYS, SPEND IN DOLLARS]])
pred=regr.predict([np.log([60, 10000])])
#68% Confidence interval
np.exp([pred[0][0]-1.65, pred[0][0]+1.65])
# Out:
# array([  603109.472151  , 16351889.34805855])

# %% [markdown]
# # Model 2: Classifier?

# %%
df['audience_size'] = df['cumulative_est_audience'].apply(lambda d: ast.literal_eval(d))
df['audience_size'] = df['audience_size'].apply(lambda d: np.array(list(d.values())).sum())
df
# Out:
#        Unnamed: 0                                 ad_creative_bodies  \
# 0               0
# 1               1  !!!The government cannot fight CORRUPTION - th...
# 2               2  !!🚨Endorsement Alert🚨!! \n\nThank you Byron Po...
# 3               3  " An astute CPA told me 45 years ago, Math nev...
# 4               4  "....Framingham should not go back to the ways...
# ...           ...                                                ...
# 11732       11732  🛡Protecting Taxpayers.\n📈Growing Our Economy.\...
# 11733       11733  🟢Today is September 26th. \n🟡On October 23rd t...
# 11734       11734  🤔 We get it—the 2022 midterm elections seem fa...
# 11735       11735  🥳❄️  Join new and old friends for our annual h...
# 11736       11736  🩺 For seniors, open enrollment ends TUESDAY, 1...
#
#                                 demographic_distribution  \
# 0      [[{'percentage': '0.000876', 'age': '45-54', '...
# 1      [[{'percentage': '0.000933', 'age': '18-24', '...
# 2      [[{'percentage': '0.004039', 'age': '65+', 'ge...
# 3      [[{'percentage': '0.00112', 'age': '18-24', 'g...
# 4      [[{'percentage': '0.004255', 'age': '45-54', '...
# ...                                                  ...
# 11732  [[{'percentage': '0.001263', 'age': '45-54', '...
# 11733  [[{'percentage': '0.003527', 'age': '45-54', '...
# 11734  [[{'percentage': '0.029101', 'age': '35-44', '...
# 11735  [[{'percentage': '0.005556', 'age': '45-54', '...
# 11736  [[{'percentage': '0.008522', 'age': '65+', 'ge...
#
#                                       delivery_by_region  \
# 0      [[{'percentage': '1', 'region': 'New York'}], ...
# 1      [[{'percentage': '0.00185', 'region': 'Rhode I...
# 2      [[{'percentage': '0.002281', 'region': 'Unknow...
# 3      [[{'percentage': '1', 'region': 'Ohio'}], [{'p...
# 4      [[{'percentage': '1', 'region': 'Massachusetts...
# ...                                                  ...
# 11732      [[{'percentage': '1', 'region': 'New York'}]]
# 11733  [[{'percentage': '0.012302', 'region': 'Florid...
# 11734  [[{'percentage': '0.005291', 'region': 'Alabam...
# 11735         [[{'percentage': '1', 'region': 'Texas'}]]
# 11736  [[{'percentage': '0.994661', 'region': 'Arizon...
#
#                                  estimated_audience_size  \
# 0      [{'lower_bound': '10001', 'upper_bound': '5000...
# 1                           [{'lower_bound': '1000001'}]
# 2      [{'lower_bound': '100001', 'upper_bound': '500...
# 3      [{'lower_bound': '100001', 'upper_bound': '500...
# 4      [{'lower_bound': '50001', 'upper_bound': '1000...
# ...                                                  ...
# 11732  [{'lower_bound': '5001', 'upper_bound': '10000'}]
# 11733  [{'lower_bound': '100001', 'upper_bound': '500...
# 11734  [{'lower_bound': '1000001'}, {'lower_bound': '...
# 11735   [{'lower_bound': '1001', 'upper_bound': '5000'}]
# 11736  [{'lower_bound': '100001', 'upper_bound': '500...
#
#                                                    spend  \
# 0      [{'lower_bound': '300', 'upper_bound': '399'},...
# 1            [{'lower_bound': '0', 'upper_bound': '99'}]
# 2         [{'lower_bound': '100', 'upper_bound': '199'}]
# 3      [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# 4      [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# ...                                                  ...
# 11732        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11733        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11734  [{'lower_bound': '0', 'upper_bound': '99'}, {'...
# 11735        [{'lower_bound': '0', 'upper_bound': '99'}]
# 11736  [{'lower_bound': '0', 'upper_bound': '99'}, {'...
#
#                                              impressions  \
# 0      [{'lower_bound': '8000', 'upper_bound': '8999'...
# 1       [{'lower_bound': '1000', 'upper_bound': '1999'}]
# 2       [{'lower_bound': '2000', 'upper_bound': '2999'}]
# 3      [{'lower_bound': '2000', 'upper_bound': '2999'...
# 4      [{'lower_bound': '0', 'upper_bound': '999'}, {...
# ...                                                  ...
# 11732   [{'lower_bound': '4000', 'upper_bound': '4999'}]
# 11733   [{'lower_bound': '1000', 'upper_bound': '1999'}]
# 11734  [{'lower_bound': '0', 'upper_bound': '999'}, {...
# 11735   [{'lower_bound': '2000', 'upper_bound': '2999'}]
# 11736  [{'lower_bound': '10000', 'upper_bound': '1499...
#
#                                   ad_delivery_start_time  \
# 0      ['2021-10-30', '2021-10-27', '2021-10-20', '20...
# 1                                         ['2021-12-16']
# 2                                         ['2021-11-16']
# 3                           ['2021-12-22', '2021-11-14']
# 4                           ['2021-11-01', '2021-10-27']
# ...                                                  ...
# 11732                                     ['2021-10-31']
# 11733                                     ['2021-09-26']
# 11734  ['2021-10-15', '2021-10-15', '2021-10-15', '20...
# 11735                                     ['2021-11-18']
# 11736                       ['2021-11-29', '2021-11-29']
#
#                                    ad_delivery_stop_time  \
# 0      ['2021-11-02', '2021-10-31', '2021-10-23', '20...
# 1                                         ['2021-12-23']
# 2                                         ['2021-11-22']
# 3                           ['2022-01-10', '2021-11-17']
# 4                           ['2021-11-02', '2021-11-01']
# ...                                                  ...
# 11732                                     ['2021-11-01']
# 11733                                     ['2021-09-30']
# 11734  ['2021-10-18', '2021-10-19', '2021-10-18', '20...
# 11735                                     ['2021-12-14']
# 11736                       ['2021-12-02', '2021-12-02']
#
#                         cumulative_impressions_by_region  cum_spend  \
# 0      {'New York': 27999.0, 'Georgia': 7000.0, 'Conn...     1347.5
# 1      {'Rhode Island': 1000.0, 'New York': 1000.0, '...       49.5
# 2              {'Unknown': 2499.5, 'New Mexico': 2499.5}      149.5
# 3                                       {'Ohio': 5999.0}       99.0
# 4      {'Massachusetts': 499.5, 'Connecticut': 0.0, '...       99.0
# ...                                                  ...        ...
# 11732                               {'New York': 4499.5}       49.5
# 11733  {'Florida': 1499.5, 'Massachusetts': 1499.5, '...       49.5
# 11734  {'Alabama': 43999.0, 'Ohio': 44998.0, 'Maine':...      992.0
# 11735                                  {'Texas': 2499.5}       49.5
# 11736  {'Arizona': 13999.0, 'California': 13999.0, 'N...       99.0
#
#                                         days_between_ads  \
# 0      TimedeltaIndex(['3 days', '4 days', '3 days', ...
# 1      TimedeltaIndex(['7 days'], dtype='timedelta64[...
# 2      TimedeltaIndex(['6 days'], dtype='timedelta64[...
# 3      TimedeltaIndex(['19 days', '3 days'], dtype='t...
# 4      TimedeltaIndex(['1 days', '5 days'], dtype='ti...
# ...                                                  ...
# 11732  TimedeltaIndex(['1 days'], dtype='timedelta64[...
# 11733  TimedeltaIndex(['4 days'], dtype='timedelta64[...
# 11734  TimedeltaIndex([ '3 days',  '4 days',  '3 days...
# 11735  TimedeltaIndex(['26 days'], dtype='timedelta64...
# 11736  TimedeltaIndex(['3 days', '3 days'], dtype='ti...
#
#       cumulative_ad_runtime  \
# 0                   33 days
# 1                    7 days
# 2                    6 days
# 3                   22 days
# 4                    6 days
# ...                     ...
# 11732                1 days
# 11733                4 days
# 11734              128 days
# 11735               26 days
# 11736                6 days
#
#                                  cumulative_est_audience  audience_size
# 0      {'New York': 1026000.0, 'Georgia': 1005001.0, ...     45631045.0
# 1      {'Rhode Island': 1000001.0, 'New York': 100000...     51000051.0
# 2          {'Unknown': 300000.5, 'New Mexico': 300000.5}       600001.0
# 3                                     {'Ohio': 600001.0}       600001.0
# 4      {'Massachusetts': 1000500.5, 'Connecticut': 10...      3000502.5
# ...                                                  ...            ...
# 11732                               {'New York': 7500.5}         7500.5
# 11733  {'Florida': 300000.5, 'Massachusetts': 300000....      9600016.0
# 11734  {'Alabama': 1035000.0, 'Ohio': 1035999.0, 'Mai...     52812972.0
# 11735                                  {'Texas': 3000.5}         3000.5
# 11736  {'Arizona': 600001.0, 'California': 600001.0, ...      2400004.0
#
# [11737 rows x 15 columns]

# %%
np.mean(new_train['spend'])
# Out:
# 3111.8956780923995
